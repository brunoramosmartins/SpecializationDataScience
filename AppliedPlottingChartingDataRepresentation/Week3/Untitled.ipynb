# %% [markdown]
# # Tarefa Prática: Compreendendo Distribuições por meio de Amostragem
#
# ***Esta tarefa é opcional e eu encorajo você a compartilhar suas soluções comigo e com seus colegas nos fóruns de discussão!***
#
#
# Para concluir esta tarefa, crie uma célula de código que:
# * Cria vários subplots usando a funcionalidade `pyplot subplots` ou `matplotlib gridspec`.
# * Cria uma animação, puxando entre 100 e 1000 amostras de cada uma das variáveis aleatórias (`x1`, `x2`, `x3`, `x4`) para cada gráfico e plotando isso como fizemos na aula sobre animação.
# * **Bônus:** Vá além e "impressione" seus colegas (e a mim!) examinando os widgets matplotlib e adicionando um widget que permite a parametrização das distribuições por trás das animações de amostragem.
#
#
# Pontas:
# * Antes de começar, pense nas diferentes maneiras de criar essa visualização para ser o mais interessante e eficaz possível.
# * Dê uma olhada nos histogramas abaixo para ter uma ideia de como são as variáveis aleatórias, bem como seu posicionamento em relação umas às outras. Este é apenas um guia, então seja criativo em como você coloca as coisas!
# * Tente manter a duração de sua animação razoável (aproximadamente entre 10 e 30 segundos).

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np

# generate 4 random variables from the random, gamma, exponential, and uniform distributions
x1 = np.random.normal(-2.5, 1, 10000)
x2 = np.random.gamma(2, 1.5, 10000)
x3 = np.random.exponential(2, 10000)+7
x4 = np.random.uniform(14,20, 10000)

# plot the histograms
plt.figure(figsize=(9,3))
plt.hist(x1, density=True, bins=20, alpha=0.5)
plt.hist(x2, density=True, bins=20, alpha=0.5)
plt.hist(x3, density=True, bins=20, alpha=0.5)
plt.hist(x4, density=True, bins=20, alpha=0.5);
plt.axis([-7,21,0,0.6])

plt.text(x1.mean()-1.5, 0.5, 'x1\nNormal')
plt.text(x2.mean()-1.5, 0.5, 'x2\nGamma')
plt.text(x3.mean()-1.5, 0.5, 'x3\nExponential')
plt.text(x4.mean()-1.5, 0.5, 'x4\nUniform');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
